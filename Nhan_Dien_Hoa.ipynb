# %% [markdown]
# <a href="https://colab.research.google.com/github/nhutd107/CNN_BT_AI/blob/main/Nhan_Dien_Hoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img
from keras.utils import img_to_array

# %%
folder = '/content/drive/MyDrive/FLOWER/'
photos, labels = list(), list()
for file in listdir(folder):
  output= 0.0
  if file.startswith('ROSE'):
    output= 1.0
  if file.startswith('DANDELION'):
    output= 2.0
  if file.startswith('DAISY'):
    output= 3.0
  if file.startswith('TULIP'):
    output= 4.0
  if file.startswith('SUNFLOWER'):
    output= 5.0
  photo = load_img(folder + file, target_size= (40,40))
  photo= img_to_array(photo)

  photos.append(photo)
  labels.append(output)

# %%
photos= asarray(photos)
labels= asarray(labels)
print(photos.shape, labels.shape)
save('/content/drive/MyDrive/Colab Notebooks/Data/flower_photos.npy', photos)
save('/content/drive/MyDrive/Colab Notebooks/Data/flower_labels.npy', labels)
# Out:
# (4247, 40, 40, 3) (4247,)

# %%
# Split data into train & test
split_index = int(0.05 * len(photos))
test_x, test_y = photos[:split_index], labels[:split_index]
train_x, train_y = photos[split_index:], labels[split_index:]

# %%
print(test_x.shape, train_x.shape)
# Out:
# (212, 40, 40, 3) (4035, 40, 40, 3)

# %%
train_x = train_x.reshape((4035, 40, 40, 3))
train_x = train_x.astype('float32')/255

test_x = test_x.reshape((212, 40, 40, 3))
test_x = test_x.astype('float32')/255

# %%
from keras.utils import to_categorical
train_y = to_categorical(train_y,6)
test_y = to_categorical(test_y,6)

# %%
from keras.models import Sequential,Model
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization,Input
from keras.optimizers import Adam
from keras import losses
loss = losses
batch_size = 64
epochs = 40
classes = 6

# %%
from keras.layers import LeakyReLU
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear', input_shape = (40, 40, 3), padding= 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(256, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(512, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(1024, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

# %%
#Đưa vào ANN, bộ ANN để phân loại:
from keras.losses import categorical_crossentropy
model.add(Flatten())
model.add(Dense(1024, activation = 'linear'))

model.add(Dense(classes, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 40, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 40, 40, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        36928
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 20, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 10, 10, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 5, 5, 256)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 3, 3, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dense_1 (Dense)             (None, 6)                 6150
#
# =================================================================
# Total params: 10,526,598
# Trainable params: 10,526,598
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile:
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
train = model.fit(train_x, train_y, batch_size= batch_size, epochs= epochs, verbose= 1)
# Out:
# Epoch 1/40
# 64/64 [==============================] - 16s 25ms/step - loss: 1.4785 - accuracy: 0.3353
# Epoch 2/40
# 64/64 [==============================] - 1s 18ms/step - loss: 1.2107 - accuracy: 0.4761
# Epoch 3/40
# 64/64 [==============================] - 1s 18ms/step - loss: 1.0703 - accuracy: 0.5579
# Epoch 4/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.9732 - accuracy: 0.6102
# Epoch 5/40
# 64/64 [==============================] - 1s 18ms/step - loss: 1.0132 - accuracy: 0.5822
# Epoch 6/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.8354 - accuracy: 0.6870
# Epoch 7/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.7631 - accuracy: 0.6957
# Epoch 8/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.6490 - accuracy: 0.7494
# Epoch 9/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.7420 - accuracy: 0.7266
# Epoch 10/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.4914 - accuracy: 0.8149
# Epoch 11/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.3460 - accuracy: 0.8724
# Epoch 12/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.3773 - accuracy: 0.8657
# Epoch 13/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.2246 - accuracy: 0.9237
# Epoch 14/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.2750 - accuracy: 0.9009
# Epoch 15/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.1586 - accuracy: 0.9435
# Epoch 16/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.2913 - accuracy: 0.8969
# Epoch 17/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0895 - accuracy: 0.9720
# Epoch 18/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0510 - accuracy: 0.9856
# Epoch 19/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0836 - accuracy: 0.9690
# Epoch 20/40
# 64/64 [==============================] - 1s 20ms/step - loss: 0.0707 - accuracy: 0.9804
# Epoch 21/40
# 64/64 [==============================] - 1s 20ms/step - loss: 0.0673 - accuracy: 0.9779
# Epoch 22/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0437 - accuracy: 0.9836
# Epoch 23/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0789 - accuracy: 0.9727
# Epoch 24/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0458 - accuracy: 0.9856
# Epoch 25/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.1197 - accuracy: 0.9641
# Epoch 26/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0834 - accuracy: 0.9715
# Epoch 27/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0544 - accuracy: 0.9814
# Epoch 28/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.1566 - accuracy: 0.9423
# Epoch 29/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0964 - accuracy: 0.9688
# Epoch 30/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0744 - accuracy: 0.9765
# Epoch 31/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0187 - accuracy: 0.9928
# Epoch 32/40
# 64/64 [==============================] - 1s 20ms/step - loss: 0.0552 - accuracy: 0.9839
# Epoch 33/40
# 64/64 [==============================] - 1s 20ms/step - loss: 0.0261 - accuracy: 0.9931
# Epoch 34/40
# 64/64 [==============================] - 1s 23ms/step - loss: 0.0107 - accuracy: 0.9963
# Epoch 35/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0197 - accuracy: 0.9936
# Epoch 36/40
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 37/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0022 - accuracy: 0.9985
# Epoch 38/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0019 - accuracy: 0.9988
# Epoch 39/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0022 - accuracy: 0.9985
# Epoch 40/40
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0019 - accuracy: 0.9985

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(test_x, test_y)
print('Test accuracy:', test_acc)
# Out:
# 7/7 [==============================] - 1s 42ms/step - loss: 2.0291 - accuracy: 0.6840
# Test accuracy: 0.6839622855186462

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/Data/flowers.h5')

# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
folder = '//content/drive/MyDrive/Test_Hoa/'
for file in listdir(folder):
  photo = load_img(folder  +  file)
  plt.imshow(photo)
  
  photo = load_img(folder +   file, target_size = (40, 40))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  class_name=['','ROSE', 'DANDELION', 'DAISY', 'TULIP', 'SUNFLOWER']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 422ms/step
# DAISY
# 1/1 [==============================] - 0s 20ms/step
# DANDELION
# 1/1 [==============================] - 0s 20ms/step
# ROSE
# 1/1 [==============================] - 0s 28ms/step
# SUNFLOWER
